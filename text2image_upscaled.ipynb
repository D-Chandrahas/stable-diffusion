# %%
# Dont forget to use a GPU accelerated runtime

# %%
# !git clone https://github.com/D-Chandrahas/stable-diffusion
# %cd stable-diffusion/models/ldm
# !mkdir stable-diffusion-v1
# %cd stable-diffusion-v1
# !curl https://www.googleapis.com/storage/v1/b/aai-blog-files/o/sd-v1-4.ckpt?alt=media > model.ckpt
# %cd ../../..
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# !bash Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local/
# !rm Miniconda3-latest-Linux-x86_64.sh
# !conda env create -f environment.yaml

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate ldm
# # run the script with custom prompt and arguments below
# # refer to [] for argument options
# python optimizedSD/text2img.py --prompt "a photo of a Corgi dog riding a bike in Times Square. It is wearing sunglasses and a beach hat" --seed 835204 --turbo --ddim_steps 200 --enhance_image --unet_bs 2
# # output images are in stable-diffusion/outputs and can be downloaded from the built-in colab file explorer
