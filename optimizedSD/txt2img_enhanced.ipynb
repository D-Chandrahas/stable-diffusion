# %%
# This notebook is designed to run in google colab
# Dont forget to use a GPU accelerated runtime

# %%
# %%shell
# cd /content
# git clone https://github.com/D-Chandrahas/stable-diffusion
# cd ./stable-diffusion/models/ldm/stable-diffusion-v1
# curl https://www.googleapis.com/storage/v1/b/aai-blog-files/o/sd-v1-4.ckpt?alt=media -o ./model.ckpt
# cd /content
# curl https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -o ./miniconda.sh
# bash ./miniconda.sh -b -p ./miniconda/
# rm ./miniconda.sh
# cd ./stable-diffusion
# conda env create -f environment.yaml

# %%
# %%shell
# eval "$(conda shell.bash hook)"
# conda activate ldm
# # run the script with custom prompt and arguments below
# # refer to https://github.com/D-Chandrahas/stable-diffusion/blob/main/README.md for argument options
# python3 optimizedSD/txt2img_enhanced.py --prompt "mona lisa" --n_samples 5 --turbo --enhance_image
# # output images are in stable-diffusion/outputs and can be downloaded from the built-in colab file explorer
